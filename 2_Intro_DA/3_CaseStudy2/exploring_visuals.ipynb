# %% [markdown]
# # Exploring with Visuals
# Use `clean_08.csv` and `clean_18.csv`

# %%
# load datasets
import pandas as pd
% matplotlib inline

df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %%
df_08.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10559a198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1132436d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1136ad278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1136dc8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x105f45f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x105f45f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x104b03cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11370f390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113737a20>]], dtype=object)

# %%
df_18.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1139e5908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113a10278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c19908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113c44f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c75668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c756a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113ccf3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113cf7a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113d28128>]], dtype=object)

# %%
# Describe the correlation between displacement and combined mpg.
df_08.plot(x='displ', y='cmb_mpg', kind='scatter');
df_18.plot(x='displ', y='cmb_mpg', kind='scatter');

# %%
# Describe the correlation between greenhouse gas score and combined mpg.
df_08.plot(x='greenhouse_gas_score', y='cmb_mpg', kind='scatter');
df_18.plot(x='greenhouse_gas_score', y='cmb_mpg', kind='scatter');
