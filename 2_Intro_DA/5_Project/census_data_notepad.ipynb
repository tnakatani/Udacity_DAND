# %%
# Import relevant libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %%
# Import NICS gun data & US census data.
# We will name the NICS gun dataset 'df1'.
# We will name the Census dataset 'df2'.
df1 = pd.read_csv('gun_data.csv')
df2 = pd.read_csv('us_census_data.csv')

# %%
# Initia
df2.head()
# Out:
#                                                 Fact Fact Note    Alabama  \
# 0       Population estimates, July 1, 2016,  (V2016)       NaN  4,863,300
# 1  Population estimates base, April 1, 2010,  (V2...       NaN  4,780,131
# 2  Population, percent change - April 1, 2010 (es...       NaN      1.70%
# 3                  Population, Census, April 1, 2010       NaN  4,779,736
# 4  Persons under 5 years, percent, July 1, 2016, ...       NaN      6.00%
#
#     Alaska    Arizona   Arkansas  California   Colorado Connecticut Delaware  \
# 0  741,894  6,931,071  2,988,248  39,250,017  5,540,545   3,576,452  952,065
# 1  710,249  6,392,301  2,916,025  37,254,522  5,029,324   3,574,114  897,936
# 2    4.50%      8.40%      2.50%       5.40%     10.20%       0.10%    6.00%
# 3  710,231  6,392,017  2,915,918  37,253,956  5,029,196   3,574,097  897,934
# 4    7.30%      6.30%      6.40%       6.30%      6.10%       5.20%    5.80%
#
#     ...    South Dakota Tennessee       Texas       Utah  Vermont   Virginia  \
# 0   ...          865454   6651194  27,862,596  3,051,217  624,594  8,411,808
# 1   ...          814195   6346298  25,146,100  2,763,888  625,741  8,001,041
# 2   ...           0.063     0.048      10.80%     10.40%   -0.20%      5.10%
# 3   ...          814180   6346105  25,145,561  2,763,885  625,741  8,001,024
# 4   ...           0.071     0.061       7.20%      8.30%    4.90%      6.10%
#
#   Washington West Virginia  Wisconsin  Wyoming
# 0  7,288,000     1,831,102  5,778,708  585,501
# 1  6,724,545     1,853,011  5,687,289  563,767
# 2      8.40%        -1.20%      1.60%    3.90%
# 3  6,724,540     1,852,994  5,686,986  563,626
# 4      6.20%         5.50%      5.80%    6.50%
#
# [5 rows x 52 columns]

# %%
df2.drop(['Fact Note'], axis=1, inplace=True)

# %%
df2 = df2.transpose()

# %%
df2.head()
# Out:
#                                                     0   \
# Fact      Population estimates, July 1, 2016,  (V2016)
# Alabama                                      4,863,300
# Alaska                                         741,894
# Arizona                                      6,931,071
# Arkansas                                     2,988,248
#
#                                                          1   \
# Fact      Population estimates base, April 1, 2010,  (V2...
# Alabama                                           4,780,131
# Alaska                                              710,249
# Arizona                                           6,392,301
# Arkansas                                          2,916,025
#
#                                                          2   \
# Fact      Population, percent change - April 1, 2010 (es...
# Alabama                                               1.70%
# Alaska                                                4.50%
# Arizona                                               8.40%
# Arkansas                                              2.50%
#
#                                          3   \
# Fact      Population, Census, April 1, 2010
# Alabama                           4,779,736
# Alaska                              710,231
# Arizona                           6,392,017
# Arkansas                          2,915,918
#
#                                                          4   \
# Fact      Persons under 5 years, percent, July 1, 2016, ...
# Alabama                                               6.00%
# Alaska                                                7.30%
# Arizona                                               6.30%
# Arkansas                                              6.40%
#
#                                                      5   \
# Fact      Persons under 5 years, percent, April 1, 2010
# Alabama                                           6.40%
# Alaska                                            7.60%
# Arizona                                           7.10%
# Arkansas                                          6.80%
#
#                                                          6   \
# Fact      Persons under 18 years, percent, July 1, 2016,...
# Alabama                                              22.60%
# Alaska                                               25.20%
# Arizona                                              23.50%
# Arkansas                                             23.60%
#
#                                                       7   \
# Fact      Persons under 18 years, percent, April 1, 2010
# Alabama                                           23.70%
# Alaska                                            26.40%
# Arizona                                           25.50%
# Arkansas                                          24.40%
#
#                                                          8   \
# Fact      Persons 65 years and over, percent,  July 1, 2...
# Alabama                                              16.10%
# Alaska                                               10.40%
# Arizona                                              16.90%
# Arkansas                                             16.30%
#
#                                                          9  ...    75  \
# Fact      Persons 65 years and over, percent, April 1, 2010 ...   NaN
# Alabama                                              13.80% ...   NaN
# Alaska                                                7.70% ...   NaN
# Arizona                                              13.80% ...   NaN
# Arkansas                                             14.40% ...   NaN
#
#                    76   77   78   79   80   81   82   83   84
# Fact      Value Flags    -    D    F   FN  NaN    S    X    Z
# Alabama           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Alaska            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Arizona           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Arkansas          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 85 columns]

# %%
df2.reset_index(level=0,inplace=True)
df2.head()
# Out:
#       index                                             0  \
# 0      Fact  Population estimates, July 1, 2016,  (V2016)
# 1   Alabama                                     4,863,300
# 2    Alaska                                       741,894
# 3   Arizona                                     6,931,071
# 4  Arkansas                                     2,988,248
#
#                                                    1  \
# 0  Population estimates base, April 1, 2010,  (V2...
# 1                                          4,780,131
# 2                                            710,249
# 3                                          6,392,301
# 4                                          2,916,025
#
#                                                    2  \
# 0  Population, percent change - April 1, 2010 (es...
# 1                                              1.70%
# 2                                              4.50%
# 3                                              8.40%
# 4                                              2.50%
#
#                                    3  \
# 0  Population, Census, April 1, 2010
# 1                          4,779,736
# 2                            710,231
# 3                          6,392,017
# 4                          2,915,918
#
#                                                    4  \
# 0  Persons under 5 years, percent, July 1, 2016, ...
# 1                                              6.00%
# 2                                              7.30%
# 3                                              6.30%
# 4                                              6.40%
#
#                                                5  \
# 0  Persons under 5 years, percent, April 1, 2010
# 1                                          6.40%
# 2                                          7.60%
# 3                                          7.10%
# 4                                          6.80%
#
#                                                    6  \
# 0  Persons under 18 years, percent, July 1, 2016,...
# 1                                             22.60%
# 2                                             25.20%
# 3                                             23.50%
# 4                                             23.60%
#
#                                                 7  \
# 0  Persons under 18 years, percent, April 1, 2010
# 1                                          23.70%
# 2                                          26.40%
# 3                                          25.50%
# 4                                          24.40%
#
#                                                    8 ...    75           76  \
# 0  Persons 65 years and over, percent,  July 1, 2... ...   NaN  Value Flags
# 1                                             16.10% ...   NaN          NaN
# 2                                             10.40% ...   NaN          NaN
# 3                                             16.90% ...   NaN          NaN
# 4                                             16.30% ...   NaN          NaN
#
#     77   78   79   80   81   82   83   84
# 0    -    D    F   FN  NaN    S    X    Z
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 86 columns]

# %%
df2.columns = df2.iloc[0]
df2.head()
# Out:
# 0      Fact  Population estimates, July 1, 2016,  (V2016)  \
# 0      Fact  Population estimates, July 1, 2016,  (V2016)
# 1   Alabama                                     4,863,300
# 2    Alaska                                       741,894
# 3   Arizona                                     6,931,071
# 4  Arkansas                                     2,988,248
#
# 0 Population estimates base, April 1, 2010,  (V2016)  \
# 0  Population estimates base, April 1, 2010,  (V2...
# 1                                          4,780,131
# 2                                            710,249
# 3                                          6,392,301
# 4                                          2,916,025
#
# 0 Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)  \
# 0  Population, percent change - April 1, 2010 (es...
# 1                                              1.70%
# 2                                              4.50%
# 3                                              8.40%
# 4                                              2.50%
#
# 0  Population, Census, April 1, 2010  \
# 0  Population, Census, April 1, 2010
# 1                          4,779,736
# 2                            710,231
# 3                          6,392,017
# 4                          2,915,918
#
# 0 Persons under 5 years, percent, July 1, 2016,  (V2016)  \
# 0  Persons under 5 years, percent, July 1, 2016, ...
# 1                                              6.00%
# 2                                              7.30%
# 3                                              6.30%
# 4                                              6.40%
#
# 0  Persons under 5 years, percent, April 1, 2010  \
# 0  Persons under 5 years, percent, April 1, 2010
# 1                                          6.40%
# 2                                          7.60%
# 3                                          7.10%
# 4                                          6.80%
#
# 0 Persons under 18 years, percent, July 1, 2016,  (V2016)  \
# 0  Persons under 18 years, percent, July 1, 2016,...
# 1                                             22.60%
# 2                                             25.20%
# 3                                             23.50%
# 4                                             23.60%
#
# 0  Persons under 18 years, percent, April 1, 2010  \
# 0  Persons under 18 years, percent, April 1, 2010
# 1                                          23.70%
# 2                                          26.40%
# 3                                          25.50%
# 4                                          24.40%
#
# 0 Persons 65 years and over, percent,  July 1, 2016,  (V2016) ...   NaN  \
# 0  Persons 65 years and over, percent,  July 1, 2...          ...   NaN
# 1                                             16.10%          ...   NaN
# 2                                             10.40%          ...   NaN
# 3                                             16.90%          ...   NaN
# 4                                             16.30%          ...   NaN
#
# 0  Value Flags    -    D    F   FN  NaN    S    X    Z
# 0  Value Flags    -    D    F   FN  NaN    S    X    Z
# 1          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 86 columns]

# %%
df2.drop(0,inplace=True)

# %%
df2.head()
# Out:
# 0        Fact Population estimates, July 1, 2016,  (V2016)  \
# 1     Alabama                                    4,863,300
# 2      Alaska                                      741,894
# 3     Arizona                                    6,931,071
# 4    Arkansas                                    2,988,248
# 5  California                                   39,250,017
#
# 0 Population estimates base, April 1, 2010,  (V2016)  \
# 1                                          4,780,131
# 2                                            710,249
# 3                                          6,392,301
# 4                                          2,916,025
# 5                                         37,254,522
#
# 0 Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)  \
# 1                                              1.70%
# 2                                              4.50%
# 3                                              8.40%
# 4                                              2.50%
# 5                                              5.40%
#
# 0 Population, Census, April 1, 2010  \
# 1                         4,779,736
# 2                           710,231
# 3                         6,392,017
# 4                         2,915,918
# 5                        37,253,956
#
# 0 Persons under 5 years, percent, July 1, 2016,  (V2016)  \
# 1                                              6.00%
# 2                                              7.30%
# 3                                              6.30%
# 4                                              6.40%
# 5                                              6.30%
#
# 0 Persons under 5 years, percent, April 1, 2010  \
# 1                                         6.40%
# 2                                         7.60%
# 3                                         7.10%
# 4                                         6.80%
# 5                                         6.80%
#
# 0 Persons under 18 years, percent, July 1, 2016,  (V2016)  \
# 1                                             22.60%
# 2                                             25.20%
# 3                                             23.50%
# 4                                             23.60%
# 5                                             23.20%
#
# 0 Persons under 18 years, percent, April 1, 2010  \
# 1                                         23.70%
# 2                                         26.40%
# 3                                         25.50%
# 4                                         24.40%
# 5                                         25.00%
#
# 0 Persons 65 years and over, percent,  July 1, 2016,  (V2016) ...   NaN  \
# 1                                             16.10%          ...   NaN
# 2                                             10.40%          ...   NaN
# 3                                             16.90%          ...   NaN
# 4                                             16.30%          ...   NaN
# 5                                             13.60%          ...   NaN
#
# 0 Value Flags    -    D    F   FN  NaN    S    X    Z
# 1         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 86 columns]

# %%
df2.rename(index=str, columns={'Fact':'state'}, inplace=True)
df2.head(1)
# Out:
# 0       state Population estimates, July 1, 2016,  (V2016)  \
# 1     Alabama                                    4,863,300
# 2      Alaska                                      741,894
# 3     Arizona                                    6,931,071
# 4    Arkansas                                    2,988,248
# 5  California                                   39,250,017
#
# 0 Population estimates base, April 1, 2010,  (V2016)  \
# 1                                          4,780,131
# 2                                            710,249
# 3                                          6,392,301
# 4                                          2,916,025
# 5                                         37,254,522
#
# 0 Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)  \
# 1                                              1.70%
# 2                                              4.50%
# 3                                              8.40%
# 4                                              2.50%
# 5                                              5.40%
#
# 0 Population, Census, April 1, 2010  \
# 1                         4,779,736
# 2                           710,231
# 3                         6,392,017
# 4                         2,915,918
# 5                        37,253,956
#
# 0 Persons under 5 years, percent, July 1, 2016,  (V2016)  \
# 1                                              6.00%
# 2                                              7.30%
# 3                                              6.30%
# 4                                              6.40%
# 5                                              6.30%
#
# 0 Persons under 5 years, percent, April 1, 2010  \
# 1                                         6.40%
# 2                                         7.60%
# 3                                         7.10%
# 4                                         6.80%
# 5                                         6.80%
#
# 0 Persons under 18 years, percent, July 1, 2016,  (V2016)  \
# 1                                             22.60%
# 2                                             25.20%
# 3                                             23.50%
# 4                                             23.60%
# 5                                             23.20%
#
# 0 Persons under 18 years, percent, April 1, 2010  \
# 1                                         23.70%
# 2                                         26.40%
# 3                                         25.50%
# 4                                         24.40%
# 5                                         25.00%
#
# 0 Persons 65 years and over, percent,  July 1, 2016,  (V2016) ...   NaN  \
# 1                                             16.10%          ...   NaN
# 2                                             10.40%          ...   NaN
# 3                                             16.90%          ...   NaN
# 4                                             16.30%          ...   NaN
# 5                                             13.60%          ...   NaN
#
# 0 Value Flags    -    D    F   FN  NaN    S    X    Z
# 1         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 86 columns]

# %%
droptest = df2.drop(df2.loc[:, 'All firms, 2012':'Z'],axis=1)

# %%
droptest.head()
# Out:
# 0       state Population estimates, July 1, 2016,  (V2016)  \
# 1     Alabama                                    4,863,300
# 2      Alaska                                      741,894
# 3     Arizona                                    6,931,071
# 4    Arkansas                                    2,988,248
# 5  California                                   39,250,017
#
# 0 Population estimates base, April 1, 2010,  (V2016)  \
# 1                                          4,780,131
# 2                                            710,249
# 3                                          6,392,301
# 4                                          2,916,025
# 5                                         37,254,522
#
# 0 Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)  \
# 1                                              1.70%
# 2                                              4.50%
# 3                                              8.40%
# 4                                              2.50%
# 5                                              5.40%
#
# 0 Population, Census, April 1, 2010  \
# 1                         4,779,736
# 2                           710,231
# 3                         6,392,017
# 4                         2,915,918
# 5                        37,253,956
#
# 0 Persons under 5 years, percent, July 1, 2016,  (V2016)  \
# 1                                              6.00%
# 2                                              7.30%
# 3                                              6.30%
# 4                                              6.40%
# 5                                              6.30%
#
# 0 Persons under 5 years, percent, April 1, 2010  \
# 1                                         6.40%
# 2                                         7.60%
# 3                                         7.10%
# 4                                         6.80%
# 5                                         6.80%
#
# 0 Persons under 18 years, percent, July 1, 2016,  (V2016)  \
# 1                                             22.60%
# 2                                             25.20%
# 3                                             23.50%
# 4                                             23.60%
# 5                                             23.20%
#
# 0 Persons under 18 years, percent, April 1, 2010  \
# 1                                         23.70%
# 2                                         26.40%
# 3                                         25.50%
# 4                                         24.40%
# 5                                         25.00%
#
# 0 Persons 65 years and over, percent,  July 1, 2016,  (V2016)  \
# 1                                             16.10%
# 2                                             10.40%
# 3                                             16.90%
# 4                                             16.30%
# 5                                             13.60%
#
# 0                  ...                   Total retail sales per capita, 2012  \
# 1                  ...                                              $12,145
# 2                  ...                                              $14,320
# 3                  ...                                              $12,927
# 4                  ...                                              $12,483
# 5                  ...                                              $12,665
#
# 0 Mean travel time to work (minutes), workers age 16 years+, 2011-2015  \
# 1                                               24.4
# 2                                                 19
# 3                                               24.8
# 4                                               21.6
# 5                                                 28
#
# 0 Median household income (in 2015 dollars), 2011-2015  \
# 1                                           $43,623
# 2                                           $72,515
# 3                                           $50,255
# 4                                           $41,371
# 5                                           $61,818
#
# 0 Per capita income in past 12 months (in 2015 dollars), 2011-2015  \
# 1                                           $24,091
# 2                                           $33,413
# 3                                           $25,848
# 4                                           $22,798
# 5                                           $30,318
#
# 0 Persons in poverty, percent Total employer establishments, 2015  \
# 1                      17.10%                              98,540
# 2                       9.90%                              20,907
# 3                      16.40%                             136,352
# 4                      17.20%                              65,175
# 5                      14.30%                             908,120
#
# 0 Total employment, 2015 Total annual payroll, 2015 ($1,000)  \
# 1              1,634,391                          67,370,353
# 2                267,999                          15,643,303
# 3              2,295,186                         102,671,393
# 4              1,003,113                          39,451,191
# 5             14,325,377                         856,954,246
#
# 0 Total employment, percent change, 2014-2015  \
# 1                                       1.90%
# 2                                       0.40%
# 3                                       2.40%
# 4                                       1.10%
# 5                                       3.50%
#
# 0 Total nonemployer establishments, 2015
# 1                                322,025
# 2                                 55,521
# 3                                451,951
# 4                                198,380
# 5                              3,206,958
#
# [5 rows x 56 columns]

# %%
# Replace df2 with just the columns we are interested in.
df2 = df2[['state',
           'Population estimates, July 1, 2016,  (V2016)',
           'White alone, percent, July 1, 2016,  (V2016)',
           'Black or African American alone, percent, July 1, 2016,  (V2016)',
           'American Indian and Alaska Native alone, percent, July 1, 2016,  (V2016)',
           'Asian alone, percent, July 1, 2016,  (V2016)',
           'Native Hawaiian and Other Pacific Islander alone, percent, July 1, 2016,  (V2016)',
           'Two or More Races, percent, July 1, 2016,  (V2016)',
           'Hispanic or Latino, percent, July 1, 2016,  (V2016)',
           'High school graduate or higher, percent of persons age 25 years+, 2011-2015',
           'Bachelor\'s degree or higher, percent of persons age 25 years+, 2011-2015',
           'Median household income (in 2015 dollars), 2011-2015',
           'Per capita income in past 12 months (in 2015 dollars), 2011-2015'
           ]]

# %%
df2.head()
# Out:
# 0       state Population estimates, July 1, 2016,  (V2016)  \
# 1     Alabama                                    4,863,300
# 2      Alaska                                      741,894
# 3     Arizona                                    6,931,071
# 4    Arkansas                                    2,988,248
# 5  California                                   39,250,017
#
# 0 White alone, percent, July 1, 2016,  (V2016)  \
# 1                                       69.30%
# 2                                       66.10%
# 3                                       83.30%
# 4                                       79.40%
# 5                                       72.70%
#
# 0 Black or African American alone, percent, July 1, 2016,  (V2016)  \
# 1                                             26.80%
# 2                                              3.80%
# 3                                              4.90%
# 4                                             15.70%
# 5                                              6.50%
#
# 0 American Indian and Alaska Native alone, percent, July 1, 2016,  (V2016)  \
# 1                                              0.70%
# 2                                             15.20%
# 3                                              5.40%
# 4                                              1.00%
# 5                                              1.70%
#
# 0 Asian alone, percent, July 1, 2016,  (V2016)  \
# 1                                        1.40%
# 2                                        6.30%
# 3                                        3.40%
# 4                                        1.60%
# 5                                       14.80%
#
# 0 Native Hawaiian and Other Pacific Islander alone, percent, July 1, 2016,  (V2016)  \
# 1                                              0.10%
# 2                                              1.30%
# 3                                              0.30%
# 4                                              0.30%
# 5                                              0.50%
#
# 0 Two or More Races, percent, July 1, 2016,  (V2016)  \
# 1                                              1.60%
# 2                                              7.30%
# 3                                              2.80%
# 4                                              2.00%
# 5                                              3.80%
#
# 0 Hispanic or Latino, percent, July 1, 2016,  (V2016)  \
# 1                                              4.20%
# 2                                              7.00%
# 3                                             30.90%
# 4                                              7.30%
# 5                                             38.90%
#
# 0 High school graduate or higher, percent of persons age 25 years+, 2011-2015  \
# 1                                             84.30%
# 2                                             92.10%
# 3                                             86.00%
# 4                                             84.80%
# 5                                             81.80%
#
# 0 Bachelor's degree or higher, percent of persons age 25 years+, 2011-2015  \
# 1                                             23.50%
# 2                                             28.00%
# 3                                             27.50%
# 4                                             21.10%
# 5                                             31.40%
#
# 0 Median household income (in 2015 dollars), 2011-2015  \
# 1                                           $43,623
# 2                                           $72,515
# 3                                           $50,255
# 4                                           $41,371
# 5                                           $61,818
#
# 0 Per capita income in past 12 months (in 2015 dollars), 2011-2015
# 1                                           $24,091
# 2                                           $33,413
# 3                                           $25,848
# 4                                           $22,798
# 5                                           $30,318

# %%
# Rename verbose column names to shorter names.
df2.rename(index=str,
           columns={'Population estimates, July 1, 2016,  (V2016)':'pop_2016',
                    'White alone, percent, July 1, 2016,  (V2016)':'white_2016',
                    'Black or African American alone, percent, July 1, 2016,  (V2016)':'black_2016',
                    'American Indian and Alaska Native alone, percent, July 1, 2016,  (V2016)':'native_2016',
                    'Asian alone, percent, July 1, 2016,  (V2016)':'asian_2016',
                    'Native Hawaiian and Other Pacific Islander alone, percent, July 1, 2016,  (V2016)':'native_pacific_2016',
                    'Two or More Races, percent, July 1, 2016,  (V2016)':'2_or_more_2016',
                    'Hispanic or Latino, percent, July 1, 2016,  (V2016)':'hispanic_2016',
                    'High school graduate or higher, percent of persons age 25 years+, 2011-2015':'hs_grad_2011_2015',
                    'Bachelor\'s degree or higher, percent of persons age 25 years+, 2011-2015':'ba_grad_2011_2015',
                    'Median household income (in 2015 dollars), 2011-2015':'med_income_2011_2015',
                    'Per capita income in past 12 months (in 2015 dollars), 2011-2015':'capita_income_2011_2015'
                   },
           inplace=True)

# %%
df2.head()
# Out:
# 0       state    pop_2016 white_2016 black_2016 native_2016 asian_2016  \
# 1     Alabama   4,863,300     69.30%     26.80%       0.70%      1.40%
# 2      Alaska     741,894     66.10%      3.80%      15.20%      6.30%
# 3     Arizona   6,931,071     83.30%      4.90%       5.40%      3.40%
# 4    Arkansas   2,988,248     79.40%     15.70%       1.00%      1.60%
# 5  California  39,250,017     72.70%      6.50%       1.70%     14.80%
#
# 0 native_pacific_2016 2_or_more_2016 hispanic_2016 hs_grad_2011_2015  \
# 1               0.10%          1.60%         4.20%            84.30%
# 2               1.30%          7.30%         7.00%            92.10%
# 3               0.30%          2.80%        30.90%            86.00%
# 4               0.30%          2.00%         7.30%            84.80%
# 5               0.50%          3.80%        38.90%            81.80%
#
# 0 ba_grad_2011_2015 med_income_2011_2015 capita_income_2011_2015
# 1            23.50%             $43,623                 $24,091
# 2            28.00%             $72,515                 $33,413
# 3            27.50%             $50,255                 $25,848
# 4            21.10%             $41,371                 $22,798
# 5            31.40%             $61,818                 $30,318

# %%
df2.dtypes
# Out:
# 0
# state                      object
# pop_2016                   object
# white_2016                 object
# black_2016                 object
# native_2016                object
# asian_2016                 object
# native_pacific_2016        object
# 2_or_more_2016             object
# hispanic_2016              object
# hs_grad_2011_2015          object
# ba_grad_2011_2015          object
# med_income_2011_2015       object
# capita_income_2011_2015    object
# dtype: object

# %%
# Remove commas and dollar signs in preparation to convert string columns to numbers.
df2['pop_2016'] = df2['pop_2016'].str.replace(',','')
df2['med_income_2011_2015'] = df2['med_income_2011_2015'].str.replace('$', '').str.replace(',','')
df2['capita_income_2011_2015'] = df2['capita_income_2011_2015'].str.replace('$', '').str.replace(',','')

# %%
df2.head()
# Out:
# 0       state  pop_2016 white_2016 black_2016 native_2016 asian_2016  \
# 1     Alabama   4863300     69.30%     26.80%       0.70%      1.40%
# 2      Alaska    741894     66.10%      3.80%      15.20%      6.30%
# 3     Arizona   6931071     83.30%      4.90%       5.40%      3.40%
# 4    Arkansas   2988248     79.40%     15.70%       1.00%      1.60%
# 5  California  39250017     72.70%      6.50%       1.70%     14.80%
#
# 0 native_pacific_2016 2_or_more_2016 hispanic_2016 hs_grad_2011_2015  \
# 1               0.10%          1.60%         4.20%            84.30%
# 2               1.30%          7.30%         7.00%            92.10%
# 3               0.30%          2.80%        30.90%            86.00%
# 4               0.30%          2.00%         7.30%            84.80%
# 5               0.50%          3.80%        38.90%            81.80%
#
# 0 ba_grad_2011_2015 med_income_2011_2015 capita_income_2011_2015
# 1            23.50%               43623                   24091
# 2            28.00%               72515                   33413
# 3            27.50%               50255                   25848
# 4            21.10%               41371                   22798
# 5            31.40%               61818                   30318

# %%
df2['pop_2016'] = df2['pop_2016'].astype('int64')
df2['med_income_2011_2015'] = df2['med_income_2011_2015'].astype('float64')
df2['capita_income_2011_2015'] = df2['capita_income_2011_2015'].astype('float64')

# %%
df2.dtypes
# Out:
# 0
# state                       object
# pop_2016                     int64
# white_2016                  object
# black_2016                  object
# native_2016                 object
# asian_2016                  object
# native_pacific_2016         object
# 2_or_more_2016              object
# hispanic_2016               object
# hs_grad_2011_2015           object
# ba_grad_2011_2015           object
# med_income_2011_2015       float64
# capita_income_2011_2015    float64
# dtype: object

# %%
# Convert cells with 'Z' to 0
df2.loc[df2['native_pacific_2016'] == 'Z','native_pacific_2016'] = 0

# %%
# Function to convert percentage cells in string datatype to float64
def p2f(x):
    return x.str.replace('%','').astype('float64')/100

# %%
# Iterate through coluns to convert string percentage to numbers.
for col in df2.loc[:, 'white_2016':'ba_grad_2011_2015']:
  df2[col] = p2f(df2[col])

# %%
df2.dtypes
# Out:
# 0
# state                       object
# pop_2016                     int64
# white_2016                 float64
# black_2016                 float64
# native_2016                float64
# asian_2016                 float64
# native_pacific_2016        float64
# 2_or_more_2016             float64
# hispanic_2016              float64
# hs_grad_2011_2015          float64
# ba_grad_2011_2015          float64
# med_income_2011_2015       float64
# capita_income_2011_2015    float64
# dtype: object

# %%
df2.head()
# Out:
# 0       state  pop_2016  white_2016  black_2016  native_2016  asian_2016  \
# 1     Alabama   4863300       0.693       0.268        0.007       0.014
# 2      Alaska    741894       0.661       0.038        0.152       0.063
# 3     Arizona   6931071       0.833       0.049        0.054       0.034
# 4    Arkansas   2988248       0.794       0.157        0.010       0.016
# 5  California  39250017       0.727       0.065        0.017       0.148
#
# 0  native_pacific_2016  2_or_more_2016  hispanic_2016  hs_grad_2011_2015  \
# 1                0.001           0.016          0.042              0.843
# 2                0.013           0.073          0.070              0.921
# 3                0.003           0.028          0.309              0.860
# 4                0.003           0.020          0.073              0.848
# 5                0.005           0.038          0.389              0.818
#
# 0  ba_grad_2011_2015  med_income_2011_2015  capita_income_2011_2015
# 1              0.235               43623.0                  24091.0
# 2              0.280               72515.0                  33413.0
# 3              0.275               50255.0                  25848.0
# 4              0.211               41371.0                  22798.0
# 5              0.314               61818.0                  30318.0

# %%
df2['state'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
#        'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)
